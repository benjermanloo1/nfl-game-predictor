# %%
import os
from io import StringIO
import pandas as pd
from bs4 import BeautifulSoup

# %%
PREDICTIONS_DIR = "data/predictions"
team_abbrev = pd.read_csv("teams.csv")

# %%
games = os.listdir(PREDICTIONS_DIR)
games = [os.path.join(PREDICTIONS_DIR, f) for f in games if f.endswith(".html")]

# %%
def parse_html(game):
    with open(game) as f:
        html = f.read()

    soup = BeautifulSoup(html)
    
    # Removing headers that would interfere with pandas
    [s.decompose() for s in soup.select("#all_team_leaders")]
    [s.decompose() for s in soup.select("#all_last_matchups")]
    [s.decompose() for s in soup.select("#bottom_nav")]
    [s.decompose() for s in soup.select('[id^="all_"][id$="_injury_report"]')]
    [s.decompose() for s in soup.select("div.media-item.logo")]

    # Test for changes
    # html_snip = soup.prettify()
    # save_path = os.path.join(PREDICTIONS_DIR, "asdf.html")
    # with open(save_path, "w+", encoding="utf-8") as f:
    #     f.write(html_snip)
    
    return soup

# %%
def read_team_ranks(soup):
    html_str = str(soup)
    html_io = StringIO(html_str)

    df = pd.read_html(html_io, attrs={"id": "teams_ranks"})[0].T

    th_tags = soup.find_all('th', {'aria-label': True})
    teams = [th['aria-label'] for th in th_tags if th.get('data-stat') != 'name']

    cols = ["Home Record", "Away Record", "Record vs. Spread", "Points Scored/Game", "Points Allowed/Game", "Takeaway Diff.", "Pass Yds/Game", 
            "Rush Yds/Game", "Def. Pass Yds/Game", "Def. Rush Yds/Game", "Tm"]

    df = df.iloc[1:].reset_index(drop=True)

    df["Tm"] = teams
    df.columns = cols

    # Removing record columns
    df = df.drop(columns=["Home Record", "Away Record", "Record vs. Spread"])

    # Remove rankings of teams within league
    df = df.replace(r'\(.*?\)', '', regex=True)

    df = df[['Tm'] + [col for col in df.columns if col != 'Tm']]

    return df

# %%
soup = parse_html(games[26])
read_team_ranks(soup)
# Out:
#     Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
# 0  LVR              17.5                26.9            -19           221
# 1  NOR              22.1                22.3             +1           210
#
#   Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game
# 0           78                208                121
# 1          124                242                134

# %%
future_games = []

for game in games:
    soup = parse_html(game)
    
    team_ranks = read_team_ranks(soup)
    teams = list(team_ranks["Tm"])
    
    summaries = []
    for team in teams:
        summary = team_ranks[team_ranks["Tm"] == team]
        
        summaries.append(summary)

    game_summary = pd.concat(summaries)

    future_game = pd.concat([game_summary])
    future_game["home"] = [0, 1]
    game_opp = future_game.iloc[::-1].reset_index()
    game_opp.columns += "_opp"

    full_game = pd.concat([future_game, game_opp], axis=1)

    full_game["season"] = "2024"  # If available
    full_game["date"] = os.path.basename(game)[:8]  # Assuming the date is part of the filename
    full_game["date"] = pd.to_datetime(full_game["date"], format="%Y%m%d")

    future_games.append(full_game)

    # Print progress every 10 games
    if len(future_games) % 10 == 0:
        print(f"{len(future_games)} / {len(games)}")
# Out:
# 10 / 48
# 20 / 48
# 30 / 48
# 40 / 48

# %%
future_games
# Out:
# [    Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  DEN              24.0                17.6             +5           202
#  1  LAC              21.0                17.6            +11           196
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          108                216                 98      0          1  ...
#  1          105                211                125      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  21.0                    17.6                +11
#  1                  24.0                    17.6                 +5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              196               105                    211
#  1              202               108                    216
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   125         1    2024 2024-12-19
#  1                    98         0    2024 2024-12-19
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  HOU              23.4                21.4            +13           212
#  1  KAN              23.5                18.5             +2           224
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          111                196                105      0          1  ...
#  1          112                215                 91      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  23.5                    18.5                 +2
#  1                  23.4                    21.4                +13
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              224               112                    215
#  1              212               111                    196
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                    91         1    2024 2024-12-21
#  1                   105         0    2024 2024-12-21
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  PIT              24.0                18.9            +18           198
#  1  BAL              29.9                23.7             +2           245
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          126                222                 94      0          1  ...
#  1          178                258                 80      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  29.9                    23.7                 +2
#  1                  24.0                    18.9                +18
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              245               178                    258
#  1              198               126                    222
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                    80         1    2024 2024-12-21
#  1                    94         0    2024 2024-12-21
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  NYG              14.9                23.4             -8           185
#  1  ATL              20.9                24.4             -7           238
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          111                200                143      0          1  ...
#  1          124                225                116      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  20.9                    24.4                 -7
#  1                  14.9                    23.4                 -8
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              238               124                    225
#  1              185               111                    200
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   116         1    2024 2024-12-22
#  1                   143         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  NWE              17.0                24.1             -7           173
#  1  BUF              31.8                22.1            +18           238
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          119                216                127      0          1  ...
#  1          130                227                117      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  31.8                    22.1                +18
#  1                  17.0                    24.1                 -7
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              238               130                    227
#  1              173               119                    216
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   117         1    2024 2024-12-22
#  1                   127         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  ARI              22.4                21.9             -2           209
#  1  CAR              17.6                29.9             -8           186
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          141                217                121      0          1  ...
#  1          102                213                173      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  17.6                    29.9                 -8
#  1                  22.4                    21.9                 -2
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              186               102                    213
#  1              209               141                    217
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   173         1    2024 2024-12-22
#  1                   121         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  DET              32.8                20.1             +7           260
#  1  CHI              19.0                22.0            +10           181
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          143                234                101      0          1  ...
#  1          106                217                133      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  19.0                    22.0                +10
#  1                  32.8                    20.1                 +7
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              181               106                    217
#  1              260               143                    234
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   133         1    2024 2024-12-22
#  1                   101         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  CLE              17.1                25.4            -16           217
#  1  CIN              28.5                27.6             +2           271
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           92                212                128      0          1  ...
#  1           91                239                126      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  28.5                    27.6                 +2
#  1                  17.1                    25.4                -16
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              271                91                    239
#  1              217                92                    212
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   126         1    2024 2024-12-22
#  1                   128         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  TEN              18.1                27.1            -13           190
#  1  IND              20.0                23.5             -4           190
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          110                182                115      0          1  ...
#  1          120                224                141      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  20.0                    23.5                 -4
#  1                  18.1                    27.1                -13
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              190               120                    224
#  1              190               110                    182
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   141         1    2024 2024-12-22
#  1                   115         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  TAM              28.8                23.3             -2           244
#  1  DAL              21.3                27.1             -5           229
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          144                247                109      0          1  ...
#  1           99                219                136      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  21.3                    27.1                 -5
#  1                  28.8                    23.3                 -2
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              229                99                    219
#  1              244               144                    247
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   136         1    2024 2024-12-22
#  1                   109         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  SFO              22.4                22.9             -4           231
#  1  MIA              19.7                22.3             -5           222
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          133                181                117      0          1  ...
#  1          101                205                103      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  19.7                    22.3                 -5
#  1                  22.4                    22.9                 -4
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              222               101                    205
#  1              231               133                    181
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   103         1    2024 2024-12-22
#  1                   117         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  LAR              22.1                24.1             +4           232
#  1  NYJ              20.2                23.2             -1           217
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          105                218                135      0          1  ...
#  1           89                193                121      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  20.2                    23.2                 -1
#  1                  22.1                    24.1                 +4
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              217                89                    193
#  1              232               105                    218
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   121         1    2024 2024-12-22
#  1                   135         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  JAX              18.8                26.9            -13           204
#  1  LVR              17.5                26.9            -19           221
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          101                264                132      0          1  ...
#  1           78                208                121      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  17.5                    26.9                -19
#  1                  18.8                    26.9                -13
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              221                78                    208
#  1              204               101                    264
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   121         1    2024 2024-12-22
#  1                   132         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  MIN              26.4                18.0             +8           236
#  1  SEA              22.5                22.4             -5           240
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          113                244                 89      0          1  ...
#  1           94                213                127      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  22.5                    22.4                 -5
#  1                  26.4                    18.0                 +8
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              240                94                    213
#  1              236               113                    244
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   127         1    2024 2024-12-22
#  1                    89         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  PHI              26.4                17.6             +3           187
#  1  WAS              28.3                22.5             +5           218
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          186                173                102      0          1  ...
#  1          155                189                132      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  28.3                    22.5                 +5
#  1                  26.4                    17.6                 +3
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              218               155                    189
#  1              187               186                    173
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   132         1    2024 2024-12-22
#  1                   102         0    2024 2024-12-22
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  NOR              22.1                22.3             +1           210
#  1  GNB              27.1                20.5            +10           231
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          124                242                134      0          1  ...
#  1          144                215                105      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  27.1                    20.5                +10
#  1                  22.1                    22.3                 +1
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              231               144                    215
#  1              210               124                    242
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   105         1    2024 2024-12-23
#  1                   134         0    2024 2024-12-23
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  BAL              29.9                23.7             +2           245
#  1  HOU              23.4                21.4            +13           212
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          178                258                 80      0          1  ...
#  1          111                196                105      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  23.4                    21.4                +13
#  1                  29.9                    23.7                 +2
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              212               111                    196
#  1              245               178                    258
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   105         1    2024 2024-12-25
#  1                    80         0    2024 2024-12-25
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  KAN              23.5                18.5             +2           224
#  1  PIT              24.0                18.9            +18           198
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          112                215                 91      0          1  ...
#  1          126                222                 94      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  24.0                    18.9                +18
#  1                  23.5                    18.5                 +2
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              198               126                    222
#  1              224               112                    215
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                    94         1    2024 2024-12-25
#  1                    91         0    2024 2024-12-25
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  SEA              22.5                22.4             -5           240
#  1  CHI              19.0                22.0            +10           181
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           94                213                127      0          1  ...
#  1          106                217                133      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  19.0                    22.0                +10
#  1                  22.5                    22.4                 -5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              181               106                    217
#  1              240                94                    213
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   133         1    2024 2024-12-26
#  1                   127         0    2024 2024-12-26
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  DEN              24.0                17.6             +5           202
#  1  CIN              28.5                27.6             +2           271
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          108                216                 98      0          1  ...
#  1           91                239                126      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  28.5                    27.6                 +2
#  1                  24.0                    17.6                 +5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              271                91                    239
#  1              202               108                    216
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   126         1    2024 2024-12-28
#  1                    98         0    2024 2024-12-28
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  LAC              21.0                17.6            +11           196
#  1  NWE              17.0                24.1             -7           173
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          105                211                125      0          1  ...
#  1          119                216                127      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  17.0                    24.1                 -7
#  1                  21.0                    17.6                +11
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              173               119                    216
#  1              196               105                    211
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   127         1    2024 2024-12-28
#  1                   125         0    2024 2024-12-28
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  ARI              22.4                21.9             -2           209
#  1  LAR              22.1                24.1             +4           232
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          141                217                121      0          1  ...
#  1          105                218                135      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  22.1                    24.1                 +4
#  1                  22.4                    21.9                 -2
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              232               105                    218
#  1              209               141                    217
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   135         1    2024 2024-12-28
#  1                   121         0    2024 2024-12-28
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  NYJ              20.2                23.2             -1           217
#  1  BUF              31.8                22.1            +18           238
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           89                193                121      0          1  ...
#  1          130                227                117      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  31.8                    22.1                +18
#  1                  20.2                    23.2                 -1
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              238               130                    227
#  1              217                89                    193
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   117         1    2024 2024-12-29
#  1                   121         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  MIA              19.7                22.3             -5           222
#  1  CLE              17.1                25.4            -16           217
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          101                205                103      0          1  ...
#  1           92                212                128      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  17.1                    25.4                -16
#  1                  19.7                    22.3                 -5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              217                92                    212
#  1              222               101                    205
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   128         1    2024 2024-12-29
#  1                   103         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  TEN              18.1                27.1            -13           190
#  1  JAX              18.8                26.9            -13           204
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          110                182                115      0          1  ...
#  1          101                264                132      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  18.8                    26.9                -13
#  1                  18.1                    27.1                -13
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              204               101                    264
#  1              190               110                    182
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   132         1    2024 2024-12-29
#  1                   115         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  GNB              27.1                20.5            +10           231
#  1  MIN              26.4                18.0             +8           236
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          144                215                105      0          1  ...
#  1          113                244                 89      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  26.4                    18.0                 +8
#  1                  27.1                    20.5                +10
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              236               113                    244
#  1              231               144                    215
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                    89         1    2024 2024-12-29
#  1                   105         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  LVR              17.5                26.9            -19           221
#  1  NOR              22.1                22.3             +1           210
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           78                208                121      0          1  ...
#  1          124                242                134      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  22.1                    22.3                 +1
#  1                  17.5                    26.9                -19
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              210               124                    242
#  1              221                78                    208
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   134         1    2024 2024-12-29
#  1                   121         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  IND              20.0                23.5             -4           190
#  1  NYG              14.9                23.4             -8           185
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          120                224                141      0          1  ...
#  1          111                200                143      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  14.9                    23.4                 -8
#  1                  20.0                    23.5                 -4
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              185               111                    200
#  1              190               120                    224
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   143         1    2024 2024-12-29
#  1                   141         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  DAL              21.3                27.1             -5           229
#  1  PHI              26.4                17.6             +3           187
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           99                219                136      0          1  ...
#  1          186                173                102      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  26.4                    17.6                 +3
#  1                  21.3                    27.1                 -5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              187               186                    173
#  1              229                99                    219
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   102         1    2024 2024-12-29
#  1                   136         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  CAR              17.6                29.9             -8           186
#  1  TAM              28.8                23.3             -2           244
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          102                213                173      0          1  ...
#  1          144                247                109      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  28.8                    23.3                 -2
#  1                  17.6                    29.9                 -8
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              244               144                    247
#  1              186               102                    213
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   109         1    2024 2024-12-29
#  1                   173         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  ATL              20.9                24.4             -7           238
#  1  WAS              28.3                22.5             +5           218
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          124                225                116      0          1  ...
#  1          155                189                132      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  28.3                    22.5                 +5
#  1                  20.9                    24.4                 -7
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              218               155                    189
#  1              238               124                    225
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   132         1    2024 2024-12-29
#  1                   116         0    2024 2024-12-29
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  DET              32.8                20.1             +7           260
#  1  SFO              22.4                22.9             -4           231
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          143                234                101      0          1  ...
#  1          133                181                117      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  22.4                    22.9                 -4
#  1                  32.8                    20.1                 +7
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              231               133                    181
#  1              260               143                    234
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   117         1    2024 2024-12-30
#  1                   101         0    2024 2024-12-30
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  CAR              17.6                29.9             -8           186
#  1  ATL              20.9                24.4             -7           238
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          102                213                173      0          1  ...
#  1          124                225                116      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  20.9                    24.4                 -7
#  1                  17.6                    29.9                 -8
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              238               124                    225
#  1              186               102                    213
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   116         1    2024 2025-01-05
#  1                   173         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  JAX              18.8                26.9            -13           204
#  1  IND              20.0                23.5             -4           190
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          101                264                132      0          1  ...
#  1          120                224                141      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  20.0                    23.5                 -4
#  1                  18.8                    26.9                -13
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              190               120                    224
#  1              204               101                    264
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   141         1    2024 2025-01-05
#  1                   132         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  SFO              22.4                22.9             -4           231
#  1  ARI              22.4                21.9             -2           209
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          133                181                117      0          1  ...
#  1          141                217                121      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  22.4                    21.9                 -2
#  1                  22.4                    22.9                 -4
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              209               141                    217
#  1              231               133                    181
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   121         1    2024 2025-01-05
#  1                   117         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  WAS              28.3                22.5             +5           218
#  1  DAL              21.3                27.1             -5           229
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          155                189                132      0          1  ...
#  1           99                219                136      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  21.3                    27.1                 -5
#  1                  28.3                    22.5                 +5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              229                99                    219
#  1              218               155                    189
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   136         1    2024 2025-01-05
#  1                   132         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  KAN              23.5                18.5             +2           224
#  1  DEN              24.0                17.6             +5           202
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          112                215                 91      0          1  ...
#  1          108                216                 98      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  24.0                    17.6                 +5
#  1                  23.5                    18.5                 +2
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              202               108                    216
#  1              224               112                    215
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                    98         1    2024 2025-01-05
#  1                    91         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  MIN              26.4                18.0             +8           236
#  1  DET              32.8                20.1             +7           260
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          113                244                 89      0          1  ...
#  1          143                234                101      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  32.8                    20.1                 +7
#  1                  26.4                    18.0                 +8
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              260               143                    234
#  1              236               113                    244
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   101         1    2024 2025-01-05
#  1                    89         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  CHI              19.0                22.0            +10           181
#  1  GNB              27.1                20.5            +10           231
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          106                217                133      0          1  ...
#  1          144                215                105      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  27.1                    20.5                +10
#  1                  19.0                    22.0                +10
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              231               144                    215
#  1              181               106                    217
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   105         1    2024 2025-01-05
#  1                   133         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  BUF              31.8                22.1            +18           238
#  1  NWE              17.0                24.1             -7           173
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          130                227                117      0          1  ...
#  1          119                216                127      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  17.0                    24.1                 -7
#  1                  31.8                    22.1                +18
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              173               119                    216
#  1              238               130                    227
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   127         1    2024 2025-01-05
#  1                   117         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  MIA              19.7                22.3             -5           222
#  1  NYJ              20.2                23.2             -1           217
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          101                205                103      0          1  ...
#  1           89                193                121      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  20.2                    23.2                 -1
#  1                  19.7                    22.3                 -5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              217                89                    193
#  1              222               101                    205
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   121         1    2024 2025-01-05
#  1                   103         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  HOU              23.4                21.4            +13           212
#  1  TEN              18.1                27.1            -13           190
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          111                196                105      0          1  ...
#  1          110                182                115      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  18.1                    27.1                -13
#  1                  23.4                    21.4                +13
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              190               110                    182
#  1              212               111                    196
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   115         1    2024 2025-01-05
#  1                   105         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  NYG              14.9                23.4             -8           185
#  1  PHI              26.4                17.6             +3           187
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          111                200                143      0          1  ...
#  1          186                173                102      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  26.4                    17.6                 +3
#  1                  14.9                    23.4                 -8
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              187               186                    173
#  1              185               111                    200
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   102         1    2024 2025-01-05
#  1                   143         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  CIN              28.5                27.6             +2           271
#  1  PIT              24.0                18.9            +18           198
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           91                239                126      0          1  ...
#  1          126                222                 94      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  24.0                    18.9                +18
#  1                  28.5                    27.6                 +2
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              198               126                    222
#  1              271                91                    239
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                    94         1    2024 2025-01-05
#  1                   126         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  LAC              21.0                17.6            +11           196
#  1  LVR              17.5                26.9            -19           221
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          105                211                125      0          1  ...
#  1           78                208                121      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  17.5                    26.9                -19
#  1                  21.0                    17.6                +11
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              221                78                    208
#  1              196               105                    211
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   121         1    2024 2025-01-05
#  1                   125         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  SEA              22.5                22.4             -5           240
#  1  LAR              22.1                24.1             +4           232
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           94                213                127      0          1  ...
#  1          105                218                135      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  22.1                    24.1                 +4
#  1                  22.5                    22.4                 -5
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              232               105                    218
#  1              240                94                    213
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   135         1    2024 2025-01-05
#  1                   127         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  CLE              17.1                25.4            -16           217
#  1  BAL              29.9                23.7             +2           245
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0           92                212                128      0          1  ...
#  1          178                258                 80      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  29.9                    23.7                 +2
#  1                  17.1                    25.4                -16
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              245               178                    258
#  1              217                92                    212
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                    80         1    2024 2025-01-05
#  1                   128         0    2024 2025-01-05
#
#  [2 rows x 21 columns],
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
#  0  NOR              22.1                22.3             +1           210
#  1  TAM              28.8                23.3             -2           244
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
#  0          124                242                134      0          1  ...
#  1          144                247                109      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
#  0                  28.8                    23.3                 -2
#  1                  22.1                    22.3                 +1
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
#  0              244               144                    247
#  1              210               124                    242
#
#    Def. Rush Yds/Game_opp home_opp  season       date
#  0                   109         1    2024 2025-01-05
#  1                   134         0    2024 2025-01-05
#
#  [2 rows x 21 columns]]

# %%
future_games_df = pd.concat(future_games, ignore_index=True)

# %%
future_games_df
# Out:
#      Tm Points Scored/Game Points Allowed/Game Takeaway Diff. Pass Yds/Game  \
# 0   DEN              24.0                17.6             +5           202
# 1   LAC              21.0                17.6            +11           196
# 2   HOU              23.4                21.4            +13           212
# 3   KAN              23.5                18.5             +2           224
# 4   PIT              24.0                18.9            +18           198
# ..  ...                ...                 ...            ...           ...
# 91  LAR              22.1                24.1             +4           232
# 92  CLE              17.1                25.4            -16           217
# 93  BAL              29.9                23.7             +2           245
# 94  NOR              22.1                22.3             +1           210
# 95  TAM              28.8                23.3             -2           244
#
#    Rush Yds/Game Def. Pass Yds/Game Def. Rush Yds/Game  home  index_opp  ...  \
# 0           108                216                 98      0          1  ...
# 1           105                211                125      1          0  ...
# 2           111                196                105      0          1  ...
# 3           112                215                 91      1          0  ...
# 4           126                222                 94      0          1  ...
# ..           ...                ...                ...   ...        ...  ...
# 91          105                218                135      1          0  ...
# 92           92                212                128      0          1  ...
# 93          178                258                 80      1          0  ...
# 94          124                242                134      0          1  ...
# 95          144                247                109      1          0  ...
#
#    Points Scored/Game_opp Points Allowed/Game_opp Takeaway Diff._opp  \
# 0                   21.0                    17.6                +11
# 1                   24.0                    17.6                 +5
# 2                   23.5                    18.5                 +2
# 3                   23.4                    21.4                +13
# 4                   29.9                    23.7                 +2
# ..                    ...                     ...                ...
# 91                  22.5                    22.4                 -5
# 92                  29.9                    23.7                 +2
# 93                  17.1                    25.4                -16
# 94                  28.8                    23.3                 -2
# 95                  22.1                    22.3                 +1
#
#    Pass Yds/Game_opp Rush Yds/Game_opp Def. Pass Yds/Game_opp  \
# 0               196               105                    211
# 1               202               108                    216
# 2               224               112                    215
# 3               212               111                    196
# 4               245               178                    258
# ..               ...               ...                    ...
# 91              240                94                    213
# 92              245               178                    258
# 93              217                92                    212
# 94              244               144                    247
# 95              210               124                    242
#
#    Def. Rush Yds/Game_opp home_opp  season       date
# 0                    125         1    2024 2024-12-19
# 1                     98         0    2024 2024-12-19
# 2                     91         1    2024 2024-12-21
# 3                    105         0    2024 2024-12-21
# 4                     80         1    2024 2024-12-21
# ..                    ...      ...     ...        ...
# 91                   127         0    2024 2025-01-05
# 92                    80         1    2024 2025-01-05
# 93                   128         0    2024 2025-01-05
# 94                   109         1    2024 2025-01-05
# 95                   134         0    2024 2025-01-05
#
# [96 rows x 21 columns]

# %%
future_games_df.to_csv("2024_nfl_prediction_games.csv")
